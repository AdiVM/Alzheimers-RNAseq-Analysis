# %%
import pandas as pd
metadata = pd.read_parquet('/home/adm808/New_CellMetadataSyn1848517.parquet')
print(metadata['broad.cell.type'].unique())
# Out:
# array(['Ex', 'Oli', 'In', 'Mic', 'Opc', 'Ast', 'End', 'Per'], dtype=object)

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from plotting import *

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import joblib

# %%
Ast = pd.read_csv("/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Genes_only_cell_on_cell_trial2/Ast/output_csv.csv")
Ast
Ast_inc = pd.read_csv("/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Genes_only_cell_on_cell_trial2/Ast/incremental_top_features_metrics.csv")
Ast_inc
# Out:
#     num_features                                  names_of_features  \
# 0              1                                            ['CPE']
# 1              2                                     ['CPE' 'SGCD']
# 2              3                               ['CPE' 'SGCD' 'ID2']
# 3              4                        ['CPE' 'SGCD' 'ID2' 'FTH1']
# 4              5                 ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP']
# 5              6          ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E']
# 6              7  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG1']
# 7              8  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG...
# 8              9  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG...
# 9             10  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG...
# 10            11  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG...
# 11            12  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG...
# 12            13  ['CPE' 'SGCD' 'ID2' 'FTH1' 'GFAP' 'MT1E' 'PRKG...
# ...

# %%
In = pd.read_csv("/n/groups/patel/adithya/Alz_Outputs/Final_Outputs/Genes_only_cell_on_cell_trial2/In/output_csv.csv")
In
# Out:
#    train_accuracy  train_roc_auc  train_avg_precision  train_recall  \
# 0        0.613796       0.715094             0.558251      0.805464
#
#    train_precision  train_f1  train_mcc  test_accuracy  test_roc_auc  \
# 0         0.487219  0.607167   0.303781       0.402685      0.376448
#
#    test_avg_precision  test_recall  test_precision   test_f1  test_mcc
# 0            0.258955     0.431271        0.254049  0.319745 -0.169472
